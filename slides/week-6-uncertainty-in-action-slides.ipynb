# %% [markdown]
# # MSDS688 -- Artifical Intelligence
#
# ## Week 6 - Acting in an Uncertain World

# %%
from IPython.display import HTML, Image, YouTubeVideo

# %%
Image('images/vaucansons-automata.png')

# %% [markdown]
# Vaucanson’s third automaton was the notorious “Defecating Duck”. While it flapped its wings and cavorted duckishly, its main attraction was that it swallowed bits of corn or grain and excreted them at the other end in a changed form. (This part of the act was a fake: the corn that went in the front remained hidden for surreptitious removal, while the rear end was preloaded.)
#
# Cite: Riskin, J. (n.d.). Frolicsome Engines: The Long Prehistory of Artificial Intelligence. Retrieved April 10, 2018, from [https://publicdomainreview.org/2016/05/04/frolicsome-engines-the-long-prehistory-of-artificial-intelligence/](https://publicdomainreview.org/2016/05/04/frolicsome-engines-the-long-prehistory-of-artificial-intelligence/)

# %% [markdown]
# ---

# %% [markdown]
# ## Basic Probability Axioms

# %% [markdown]
# * $P(True) = 1 \quad  P(False) = 0$

# %% [markdown]
# * $0 <= P(A) <= 1 \quad\text{where A is an event}$

# %% [markdown]
# * $P(A \cup B) = P(A) + P(B) - P(A \cap B) \quad\text{where A and b are events}$

# %% [markdown]
# Note:  if A and B are **disjoint or mutually exclusive** (no overlap) --> **P(A U B) = P(A) + P(B)**
#
# Example: Set of odd and even numbers is disjoint

# %% [markdown]
# ## Mutually Exclusive Events - Cannot happen together

# %%
Image('images/probability-a-or-b.png')

# %% [markdown]
# cite: https://www.onlinemathlearning.com/mutually-exclusive-events.html

# %% [markdown]
# ## Conditional Probability
#
# * $P(A \mid B) = \frac{P(A \cap B)}{P(B)}$

# %% [markdown]
# ## Chain Rule

# %% [markdown]
# * $P(A\,B) = P(A\mid B) \;P(B)$

# %% [markdown]
# * $\text{How about for 3 variables?} \;\; P(A\,B\,C)$

# %% [markdown]
# * $P(A\,B\,C) = P(A y) = P(A\mid y) \;P(y) \;\;\text let \;  y\,=\,BC$

# %% [markdown]
# * $ P(A\,B\,C) = P(A \mid B C)\; P(B C)$

# %% [markdown]
# * $ P(A\,B\,C) = P(A \mid BC)\; P(B \mid C)\; P(C)$

# %% [markdown]
# * $P(A_1 A_2 A_3 \dots A_N) =  P(A_1 \mid A_2 \dots A_{n}) \; P(A_2 \mid A_3 \dots A_{n}) \dots P(A_n)$

# %% [markdown]
# ## Independent Events

# %% [markdown]
# * Independent events do not effect one another

# %% [markdown]
# * Independent events can occur together

# %% [markdown]
# * $P(AB) = P(A)\;\bullet\;P(B)$

# %% [markdown]
# * $P(A \mid B) = P(A) \;\; \text{iff} \; A \; \text{independent from } B$

# %% [markdown]
# ## Example of Independence

# %% [markdown]
# * P(A)=1/3 --> probability it rains tomorrow

# %% [markdown]
# * P(B)=1/2 --> probability of heads

# %% [markdown]
# * What is P(A|B)?

# %% [markdown]
# * P(A|B) = P(A) = 1/3 --> coin toss does not have anything to do with tomorrow's weather

# %% [markdown]
# cite: https://www.probabilitycourse.com/chapter1/1_4_4_conditional_independence.php

# %% [markdown]
# ## Conditional Independence

# %% [markdown]
# * Assuming A is independent from B

# %% [markdown]
# * $P(A \mid B, C) = P(A \mid C)$

# %% [markdown]
# * $P(A, B \mid C) = P(A \mid C) \;\bullet\  P(B \mid C)$

# %% [markdown]
# * $P(A \mid B, C) = P(A  \mid B) \;\bullet\  P(A  \mid C)$

# %% [markdown]
# ## Bayes Theorem

# %% [markdown]
# <p>
# $P(A\mid B) = \frac{P(B\mid A)P(A)}{P(B)}$
# </p>

# %% [markdown]
# ## Joint Probability Table

# %% [markdown]
# | Burglary | Earthquake | Alarm | MaryCalls | JohnCalls | Count | Probablity |
# |----------|:----------:|:-----:|:---------:|:---------:|:-----:|-----------:|
# |     T    |      T     |   T   |     T     |     T     |  c_1  |    p_1     |
# |   ...    |    ...     |  ...  |    ...    |    ...    |  ...  |    ...     |
# |     F    |      F     |   F   |     F     |     F     |  c_n  |    p_n     |

# %% [markdown]
# * How many values does it take to fully specify the probability of each event?

# %% [markdown]
# ## How large is a JPT?

# %% [markdown]
# * Assuming a boolean T / F domain gives us 2 for the base

# %% [markdown]
# * 7 variables gives our exponent

# %% [markdown]
# * General solution:     (size_of_domain ** num_vars) - 1

# %% [markdown]
# * Exact solution: **2^7 - 1 = 127**

# %% [markdown]
# * But why the -1?

# %% [markdown]
#
# * Probabilities sum to 1

# %% [markdown]
# * Sum the P(1 ... n-1) values and subtract from 1

# %% [markdown]
# ---

# %% [markdown]
# # Break
#
# ![Bayes by the seashore](https://imgs.xkcd.com/comics/seashell.png )

# %% [markdown]
# ---

# %% [markdown]
# ## Bayesian Belief Network

# %% [markdown]
# * Combination of probability and graph theory

# %% [markdown]
# * Nodes are random variables with probability values

# %% [markdown]
# * Edges are conditional dependencies and model causality

# %%
Image('images/bayes-net-toothache-model.png')

# %%
Image('images/Figure-S14-2-bayesian-belief-net.png')

# %%
Image('images/bayes-net-competing-models.png')

# %%
Image('images/bayes-net-car-insurance.png')

# %% [markdown]
# ### Citation
#
# “Artificial Intelligence: A Modern Approach(4th Ed.).” Artificial Intelligence: A Modern Approach, 2020, aima.cs.berkeley.edu/.  PDF file under Figures tab. http://aima.cs.berkeley.edu/figures.pdf.

# %% [markdown]
# ## Goal: Joint Probability Table to Bayes Net Roundtrip
#
# 1. Basic probability
# 1. Chain rule
# 1. Conditional independence
# 1. Bayes theorem
# 1. Naive Bayes modeling assumption
# 1. Directed Acyclic Graphs (DAG)
# 1. Sort the DAG

# %% [markdown]
# ---

# %% [markdown]
# # Demonstration

# %% [markdown]
# ---

# %% [markdown]
# # Exercise

# %%
Image('images/pwinston-inference-net.png')
