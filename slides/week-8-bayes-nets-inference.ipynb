# %%
from IPython.display import HTML, Image, YouTubeVideo

# %% [markdown]
# # MSDS688 -- Artifical Intelligence
#
# ## Week 7 - Bayes Nets

# %%
Image('images/eavesdropping.png')

# %% [markdown]
# Eavesdropping is a unique collaboration between Liquid Architecture, Melbourne Law School and the Ian Potter Museum of Art, comprising gram, series of working groups and touring event which explores the politics of listening through work by leading artists, researchers, writers and activists from Australia and around the world.

# %% [raw]
# ## Learning Objectives
#
# 1. Inference using Bayesian networks (aka Bayes nets)
#
# 1. Simulating data using a Bayesian Network
#
# 1. Issues with Bayesian Networks

# %% [markdown]
# # Bayes net assumption
#
# > _Each variable is conditionally independent of its non-descendants, given its parents._

# %% [markdown]
# ## Chain Rule

# %% [markdown]
# * $ P(A\,B\,C) = P(A \mid BC)\; P(B \mid C)\; P(C)$

# %% [markdown]
# * $P(A_1 A_2 A_3 \dots A_N) =  P(A_1 \mid A_2 \dots A_{n}) \; P(A_2 \mid A_3 \dots A_{n}) \dots P(A_n)$

# %% [markdown]
# ## Independence

# %% [markdown]
# * $P(AB) = P(A)\;\bullet\;P(B)\;\; \text{iff} \; A \; \text{independent from } B$

# %% [markdown]
# * $P(A \mid B) = P(A) \;\; \text{iff} \; A \; \text{independent from } B$

# %% [markdown]
# ## Conditional Independence

# %% [markdown]
# * $P(A \mid B, C) = P(A \mid C)  \;\; \text{iff} \; A \; \text{independent from } $

# %% [markdown]
# * $P(A, B \mid C) = P(A \mid C) \;\bullet\  P(B \mid C) \;\; \text{iff} \; A \; \text{independent from } B$

# %% [markdown]
# * $P(A \mid B, C) = P(A  \mid B) \;\bullet\  P(A  \mid C)  \;\; A \;\; \text{iff} \; A \; \text{independent from } B$

# %% [markdown]
# # Applying Probability

# %% [markdown]
# * Order the variable descendants first

# %% [markdown]
# * Select a joint probability to compute

# %% [markdown]
# * Apply conditional independence based on the Bayes net assumption

# %% [markdown]
# * Eliminates independent variables from the givens in the conditional probabilities

# %% [markdown]
# # Example

# %%
Image('./images/Figure-S14-2-bayesian-belief-net.png')

# %% [markdown]
# # Applications

# %% [markdown]
# * Find any joint probability table value

# %% [markdown]
# * Naive Bayes Classification

# %% [markdown]
# * Select the best model

# %% [markdown]
# # Variable Elimination

# %% [markdown]
# * Computing an exact posterior distribution from Bayes nets in intractable

# %% [markdown]
# * Estimation is the way!

# %% [markdown]
# * Methods
#   * Variable elimination
#   * Stochastic simulation

# %% [markdown]
# * Variable Elimination
#   * Approximate the problem
#   * Find an approximation that is similar to the original problem
#   * Estimate the posterior probability while minimizing the error

# %% [markdown]
# # Citations
#
# * Stern, J., & Parker, D. (Eds.). (n.d.). Eavesdropping. Retrieved August 20, 2018, from [www.art-museum.unimelb.edu.au/exhibitions/future-exhibitions/exhib-date/2018-07-24/exhib/eavesdropping](http://www.art-museum.unimelb.edu.au/exhibitions/future-exhibitions/exhib-date/2018-07-24/exhib/eavesdropping) -
